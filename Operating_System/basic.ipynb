# %% [markdown]
# The os module allows Python programs to communicate with the operating system. It is used for creating folders, deleting files, checking paths, changing directories, and many other system-related tasks.

# %%
import os

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\adity\OneDrive\Desktop\45_days_Training\Operating_System

# %%
os.listdir(r"C:\Users\adity\OneDrive\Pictures\Screenshots")
# Out:
# ['desktop.ini',
#  'Screenshot 2025-11-18 171052.png',
#  'Screenshot 2025-11-18 171110.png',
#  'Screenshot 2025-11-19 205343.png',
#  'Screenshot 2025-11-19 205404.png',
#  'Screenshot 2026-01-04 204302.png',
#  'Screenshot 2026-01-04 212458.png',
#  'Screenshot 2026-01-04 212506.png',
#  'Screenshot 2026-01-04 220631.png',
#  'Screenshot 2026-01-04 220645.png',
#  'Screenshot 2026-01-05 134302.png',
#  'Screenshot 2026-01-06 222241.png',
#  'Screenshot 2026-01-25 131702.png',
#  'Screenshot 2026-03-05 220131.png',
#  'Screenshot 2026-03-05 220152.png',
#  'Screenshot 2026-03-21 000836.png',
#  'Screenshot 2026-03-21 000957.png',
#  'Screenshot 2026-04-22 193216.png',
#  'Screenshot 2026-04-22 193246.png',
#  'Screenshot 2026-04-22 193550.png',
#  'Screenshot 2026-05-21 214714.png',
#  'Screenshot 2026-05-21 214744.png',
#  'Screenshot 2026-05-28 155332.png']

# %%
os.listdir()   #return current dir
# Out:
# ['basic.ipynb']

# %%
os.mkdir("crete_new_folder")  ## it create new file

# %%
import os

os.rename("new.txt","old.txt")

print("file renamed")
