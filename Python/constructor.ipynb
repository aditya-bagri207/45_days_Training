# %%
# constructor

class College:
    def __init__(self):
        pass
st = College()

# %%
#default constructor
class College:
    college_name = "BKBIET"     # class variable 
    def __init__(self):
        self.name = "Aaditya"     #intance variable 
        self.classes = "secomd year"

st = College()

# %%
st.name
# Out:
# 'Aaditya'

# %%
st.classes
# Out:
# 'secomd year'

# %%
#paramiterized constructor
class College:
    college_name = "BKBIET"     # class variable 
    def __init__(self,name,classes):
        self.name = name     #intance variable 
        self.classes = classes

st = College("aditya", "second year")

# %%
st.classes
# Out:
# 'second year'

# %%
st.name
# Out:
# 'aditya'

# %%
#using constructor varible by the help of function

class College:
    college_name = "BKBIET"     # class variable 
    def __init__(self,name,classes):
        self.name = name     #intance variable 
        self.classes = classes

    def account(self):               
        print(f"my name is {self.name} and my class is {self.classes}")


st = College("aditya", "second year")

# %%
st.account()
# Out:
# my name is aditya and my class is second year

# %%
class Vehicles:

    def __init__(self):
        self.type = "cars"
        self.type2 = "bike"

class Bike(Vehicles):
    def __init__(self):
        self.name = "honda"
        self.no = "rj14"

class car(Bike):
    def __init__
