# %%
import matplotlib.pyplot as plt

print("Matplotlib installed successfully!")
# Out:
# Matplotlib installed successfully!

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6,7,8,9]
y = [1,2,3,4,5,6,7,8,9]

plt.plot(x, y)
plt.show()

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\adity\OneDrive\Desktop\45_days_Training\Pandas\Titanic_test.csv")

plt.plot(df["Age"], df["Fare"],"r",marker = "*")
plt.show()

# %%
plt.bar(df["Age"], df["Fare"])
# Out:
# <BarContainer object of 418 artists>
