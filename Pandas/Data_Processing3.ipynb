# %%
import pandas as pd

df = pd.read_csv("Titanic_test.csv")
print(df)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    str
#  3   Sex          418 non-null    str
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    str
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     str
#  10  Embarked     418 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 36.1 KB

# %%
df["Cabin"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 413     NaN
# 414    C105
# 415     NaN
# 416     NaN
# 417     NaN
# Name: Cabin, Length: 418, dtype: str

# %%
df.sort_values("Fare")
# Out:
#      PassengerId  Pclass                                               Name  \
# 372         1264       1                            Ismay, Mr. Joseph Bruce
# 266         1158       1              Chisholm, Mr. Roderick Robert Crispin
# 21           913       3                          Olsen, Master. Artur Karl
# 133         1025       3                              Thomas, Mr. Charles P
# 116         1008       3                                   Thomas, Mr. John
# ..           ...     ...                                                ...
# 375         1267       1                           Bowen, Miss. Grace Scott
# 53           945       1                         Fortune, Miss. Ethel Flora
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 152         1044       3                                 Storey, Mr. Thomas
#
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.drop("Cabin", axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
df[df["Fare"].isnull()]
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      Fare Embarked
# 152   NaN        S

# %%
df.loc[152, "Fare"] = 574

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.to_csv("cleaned titanic data set.csv")  #this download  the cleaned data set

# %%
df.groupby("Pclass")["Fare"].mean()
# Out:
# Pclass
# 1    94.280297
# 2    22.202104
# 3    15.035551
# Name: Fare, dtype: float64

# %%
df.groupby("Pclass")["Fare"].sum()
# Out:
# Pclass
# 1    10087.9918
# 2     2064.7957
# 3     3277.7501
# Name: Fare, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.scatter(df["PassengerId"],df["Fare"])
plt.title("plot between passengerID and Fare")
plt.xlabel("PassengerId")
plt.ylabel("Fare")
# Out:
# Text(0, 0.5, 'Fare')

# %%
plt.boxplot(df["Fare"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19d602d6510>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19d602d67b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19d602d63c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x19d602d6a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19d602d6ba0>],
#  'means': []}

# %%
Fare1 = df.groupby("Pclass")["Fare"].sum()
plt.fill_between(
   Fare1.index,
   Fare1.values
)

# %%
fig,ax = plt.subplots(2,1)
ax[0].scatter(df["Age"],df["Fare"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img = plt.imread("wallpaper.jpg")

# %%
plt.imshow(img)

# %%
df.plot()
# Out:
# <Axes: >
