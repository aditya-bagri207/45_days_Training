# %% [markdown]
# Pandas (Theory)
#
# Pandas is an open-source Python library used for data analysis and data manipulation. It helps in handling and organizing large amounts of data in a structured form.
#
# Features of Pandas
# Fast and efficient data handling.
# Easy reading and writing of data from files (CSV, Excel, etc.).
# Supports data cleaning and preprocessing.
# Provides statistical analysis tools.
# Handles missing data effectively.
# Main Data Structures
# 1. Series
# A one-dimensional labeled array.
# Can store data of any type (integers, strings, floats, etc.).
# Similar to a single column in a table.
# 2. DataFrame
# A two-dimensional data structure.
# Consists of rows and columns.
# Similar to a spreadsheet or database table.
# Most commonly used structure in Pandas.
# Common Uses of Pandas
# Data cleaning
# Data transformation
# Data analysis
# Data visualization preparation
# Working with CSV and Excel files
# Advantages
# Easy to learn and use.
# Saves time when working with large datasets.
# Integrates well with libraries like NumPy and Matplotlib.

# %%
import numpy as np
data = np.array([["a",25,5000],["b",30,10000]])
print(data)
# Out:
# [['a' '25' '5000']
#  ['b' '30' '10000']]

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'London', 'Paris']}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris

# %%
import pandas as pd
df = pd.DataFrame([["a",25,1000],["b",35,2000]])
print(df)
# Out:
#    0   1     2
# 0  a  25  1000
# 1  b  35  2000

# %%
s  = pd.Series([80,40,50])
print(s)
#index base print
print(s[0])
# Out:
# 0    80
# 1    40
# 2    50
# dtype: int64
# 80

# %%
p = pd.Series([80,40,48],index = ["math","science","english"])
print(p)
#label base
print(p["math"])
# Out:
# math       80
# science    40
# english    48
# dtype: int64

# %%
import pandas as pd
d = pd.Series([10,20,30])
print(d+1)
print(d*2)
# Out:
# 0    11
# 1    21
# 2    31
# dtype: int64
# 0    20
# 1    40
# 2    60
# dtype: int64

# %%
data ={
    "name": ["Aditya","Dhruv","mohan"],
    "Age": [2,3,4],
    "Marks": [50,60,70]

}
df = pd.Series(data)
print(df)
df = pd.DataFrame(data)
print(df)
# Out:
# name     [Aditya, Dhruv, mohan]
# Age                   [2, 3, 4]
# Marks              [50, 60, 70]
# dtype: object
#      name  Age  Marks
# 0  Aditya    2     50
# 1   Dhruv    3     60
# 2   mohan    4     70

# %%
import pandas as pd
data ={
    "name": ["Aditya","Dhruv","mohan"],
    "Age": [2,3,4],
    "Marks": [50,60,70]

}

df = pd.DataFrame(data)
print(df)

df["City"] = ["jaipur","pilani","pali"]
print(df)
# Out:
#      name  Age  Marks
# 0  Aditya    2     50
# 1   Dhruv    3     60
# 2   mohan    4     70
#      name  Age  Marks    City
# 0  Aditya    2     50  jaipur
# 1   Dhruv    3     60  pilani
# 2   mohan    4     70    pali

# %%
#remove a column
df = df.drop('City', axis=1)
print(df)
# Out:
#      name  Age  Marks
# 0  Aditya    2     50
# 1   Dhruv    3     60
# 2   mohan    4     70

# %%
#rename a column
df.rename(columns={'Age': 'Years'}, inplace=True)

print(df)
# Out:
#      name  Years  Marks
# 0  Aditya      2     50
# 1   Dhruv      3     60
# 2   mohan      4     70
